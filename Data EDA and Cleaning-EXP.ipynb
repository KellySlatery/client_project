# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# # EDA

# %%
df1 = pd.read_csv('data/project_data/combined_train_data.csv')
df1.shape
# Out:
# (173977, 5)

# %% [markdown]
# ### Routine EDA

# %%
df1.head(2)
# Out:
#    Unnamed: 0                          0             1  \
# 0  0           2016-10-30 20:51:45+00:00  DentonPolice
# 1  1           2016-10-30 16:59:03+00:00  DentonPolice
#
#                                                                                                                                                                                                                                 2  \
# 0  Investigating mismatch of name / photo. Until then, view the source directly from "City Jail Custody Report" page: http://dpdjailview.cityofdenton.com/
# 1  10/30/2016 08:44:23 Regina, 39 yrs old Bond: $10,000 DRIVING WHILE INTOXICATED 3RD OR MORE https://www.change.org/petitions/denton-police-department-make-mug-shots-available-on-request-instead-of-putting-all-of-them-online
#
#      3
# 0  NaN
# 1  NaN

# %%
df1.isna().sum()
# Out:
# Unnamed: 0    0
# 0             0
# 1             0
# 2             1052
# 3             120762
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173977 entries, 0 to 173976
# Data columns (total 5 columns):
# Unnamed: 0    173977 non-null int64
# 0             173977 non-null object
# 1             173977 non-null object
# 2             172925 non-null object
# 3             53215 non-null object
# dtypes: int64(1), object(4)
# memory usage: 6.6+ MB

# %%
df1.rename(columns={'1':'user', '3':'hashtage', '2':'tweet', '0': 'dates&time'}, inplace =True)

# %%
df1.head(2)
# Out:
#    Unnamed: 0                 dates&time          user  \
# 0  0           2016-10-30 20:51:45+00:00  DentonPolice
# 1  1           2016-10-30 16:59:03+00:00  DentonPolice
#
#                                                                                                                                                                                                                             tweet  \
# 0  Investigating mismatch of name / photo. Until then, view the source directly from "City Jail Custody Report" page: http://dpdjailview.cityofdenton.com/
# 1  10/30/2016 08:44:23 Regina, 39 yrs old Bond: $10,000 DRIVING WHILE INTOXICATED 3RD OR MORE https://www.change.org/petitions/denton-police-department-make-mug-shots-available-on-request-instead-of-putting-all-of-them-online
#
#   hashtage
# 0  NaN
# 1  NaN

# %%
df1.drop(['Unnamed: 0', 'hashtage'], axis = 1, inplace = True)

# %%
df1.shape
# Out:
# (173977, 3)

# %%
df1['tweet'] = df1['tweet'].str.replace('http\S+|www.\S+', '', case = False)

# %%
df1.head(2)
# Out:
#                   dates&time          user  \
# 0  2016-10-30 20:51:45+00:00  DentonPolice
# 1  2016-10-30 16:59:03+00:00  DentonPolice
#
#                                                                                                                  tweet
# 0  Investigating mismatch of name / photo. Until then, view the source directly from "City Jail Custody Report" page:
# 1  10/30/2016 08:44:23 Regina, 39 yrs old Bond: $10,000 DRIVING WHILE INTOXICATED 3RD OR MORE

# %%
#df1['tweet'] = df1['tweet'].replace('[^a-zA-Z ]', '', regex=True)

# %%
df1.head()
# Out:
#                   dates&time          user  \
# 0  2016-10-30 20:51:45+00:00  DentonPolice
# 1  2016-10-30 16:59:03+00:00  DentonPolice
# 2  2016-10-30 13:52:19+00:00  DentonPolice
# 3  2016-10-26 21:45:57+00:00  DentonPolice
# 4  2016-10-26 21:09:45+00:00  DentonPolice
#
#                                                                                                                  tweet
# 0  Investigating mismatch of name / photo. Until then, view the source directly from "City Jail Custody Report" page:
# 1  10/30/2016 08:44:23 Regina, 39 yrs old Bond: $10,000 DRIVING WHILE INTOXICATED 3RD OR MORE
# 2  10/29/2016 17:03:18 Steven, 26 yrs old Bond: $2,024 SPEEDING 73MPH IN A 55MPH ZONE DL DRIVING WHILE LICENSE INVALI
# 3  10/25/2016 22:59:57 Monique, 39 yrs old Bond: $500 POSS MARIJ &lt; 2OZ
# 4  10/25/2016 21:37:00 Katelyn, 24 yrs old Bond: $500 PUBLIC INTOXICATION-NON-ALCOHOL

# %% [markdown]
# ### Apply Filters

# %%
#CR: mask idea goes to GA alumn team Nick Cote, Fausto De La Rosa Mañón and Ilya Kvyatkovskiy

# First filter layer 

# Depends on the data, filter contents can be adjusted.

mask1_1 = df1['tweet'].str.contains('roa', regex = False, case = False, na=False)
mask1_2 = df1['tweet'].str.contains('stree', regex = False, case = False, na=False)
mask1_3 = df1['tweet'].str.contains('highway', regex = False, case = False, na=False)
mask1_4 = df1['tweet'].str.contains('ramp', regex=False, case=False, na=False)
mask1_5 = df1['tweet'].str.contains('st', regex=False, case=False, na=False)
mask1_6 = df1['tweet'].str.contains('ave', regex=False, case=False, na=False)
mask1_7 = df1['tweet'].str.contains('lane', regex=False, case=False, na=False)
mask1_8 = df1['tweet'].str.contains('ln', regex=False, case=False, na=False)
mask1_9 = df1['tweet'].str.contains('drive', regex=False, case=False, na=False)
mask1_0 = df1['tweet'].str.contains('closed', regex=False, case=False,na=False)


layer_1 = (mask1 | mask2 | mask3 | mask4 | mask5 | mask6 | mask7 | mask8 | mask9)&(mask0)

# %%
df_1 = df1[layer_1]

# %%
#df_1.duplicated().sum()

# %%
#df_1.drop_duplicates(keep='first', inplace = True)

# %%
#df_1['category '] = 1

# %%
df_1.head(100)
# Out:
#                       dates&time             user  \
# 4959   2020-02-06 22:03:12+00:00  DallasPD
# 5684   2019-10-23 18:36:51+00:00  DallasPD
# 5712   2019-10-20 17:37:14+00:00  DallasPD
# 5718   2019-10-19 01:32:05+00:00  DallasPD
# 5719   2019-10-19 01:18:25+00:00  DallasPD
# 5733   2019-10-16 19:24:26+00:00  DallasPD
# 5740   2019-10-14 21:18:21+00:00  DallasPD
# 5744   2019-10-14 18:18:02+00:00  DallasPD
# 5749   2019-10-12 17:31:19+00:00  DallasPD
# 5761   2019-10-11 19:30:56+00:00  DallasPD
# 5795   2019-10-05 19:05:09+00:00  DallasPD
# 5826   2019-09-28 19:58:48+00:00  DallasPD
# 5827   2019-09-28 18:36:37+00:00  DallasPD
# 5983   2019-08-30 21:16:20+00:00  DallasPD
# 6062   2019-08-14 22:31:39+00:00  DallasPD
# 6175   2019-07-13 22:04:27+00:00  DallasPD
# 6177   2019-07-13 01:38:19+00:00  DallasPD
# 6364   2019-06-09 21:42:32+00:00  DallasPD
# 6699   2019-04-10 16:34:57+00:00  DallasPD
# 6749   2019-03-29 02:45:01+00:00  DallasPD
# 6891   2019-02-28 14:36:18+00:00  DallasPD
# 6930   2019-02-23 02:33:30+00:00  DallasPD
# 7591   2018-10-06 13:52:19+00:00  DallasPD
# 7806   2018-08-17 11:56:11+00:00  DallasPD
# 7841   2018-08-13 16:37:58+00:00  DallasPD
# 7859   2018-08-10 15:03:02+00:00  DallasPD
# 8137   2018-05-31 20:14:19+00:00  DallasPD
# 8231   2018-05-05 20:05:11+00:00  DallasPD
# 8232   2018-05-05 14:14:51+00:00  DallasPD
# 8428   2018-03-15 16:33:33+00:00  DallasPD
# 8546   2018-02-19 19:01:25+00:00  DallasPD
# 8547   2018-02-19 17:01:24+00:00  DallasPD
# 8548   2018-02-19 16:42:29+00:00  DallasPD
# 8550   2018-02-19 10:03:27+00:00  DallasPD
# 9090   2017-10-14 20:31:30+00:00  DallasPD
# 9095   2017-10-14 02:26:26+00:00  DallasPD
# 9163   2017-10-07 17:25:19+00:00  DallasPD
# 9164   2017-10-07 17:11:35+00:00  DallasPD
# 9207   2017-10-02 13:48:14+00:00  DallasPD
# 9233   2017-09-29 18:22:52+00:00  DallasPD
# 9504   2017-08-18 20:56:20+00:00  DallasPD
# 9517   2017-08-16 17:49:26+00:00  DallasPD
# 9519   2017-08-16 16:46:42+00:00  DallasPD
# 10001  2017-06-05 15:16:56+00:00  DallasPD
# 10263  2017-05-01 17:39:39+00:00  DallasPD
# 10315  2017-04-24 17:49:17+00:00  DallasPD
# 10583  2017-03-16 21:02:48+00:00  DallasPD
# 10629  2017-03-10 22:14:04+00:00  DallasPD
# 10630  2017-03-10 22:13:44+00:00  DallasPD
# 10631  2017-03-10 21:39:57+00:00  DallasPD
# 10691  2017-03-03 02:52:55+00:00  DallasPD
# 10726  2017-02-23 21:02:58+00:00  DallasPD
# 10925  2017-01-25 19:17:58+00:00  DallasPD
# 11505  2016-10-19 17:57:42+00:00  DallasPD
# 11509  2016-10-19 16:15:16+00:00  DallasPD
# 11606  2016-10-08 19:42:02+00:00  DallasPD
# 11610  2016-10-08 16:06:12+00:00  DallasPD
# 11611  2016-10-08 15:35:53+00:00  DallasPD
# 11828  2016-09-19 19:03:44+00:00  DallasPD
# 12814  2016-06-15 16:59:47+00:00  DallasPD
# 12838  2016-06-13 03:45:23+00:00  DallasPD
# 12842  2016-06-13 02:41:50+00:00  DallasPD
# 13641  2016-04-08 20:19:53+00:00  DallasPD
# 14108  2016-03-02 17:18:58+00:00  DallasPD
# 14581  2016-01-18 15:02:14+00:00  DallasPD
# 14741  2019-10-30 12:52:41+00:00  beaumont_police
# 14779  2019-09-19 15:51:49+00:00  beaumont_police
# 14786  2019-09-19 12:28:17+00:00  beaumont_police
# 14809  2019-07-31 20:49:12+00:00  beaumont_police
# 14811  2019-07-31 13:42:41+00:00  beaumont_police
# 14844  2019-05-25 04:04:15+00:00  beaumont_police
# 14882  2019-03-28 13:09:09+00:00  beaumont_police
# 14883  2019-03-28 12:51:02+00:00  beaumont_police
# 14953  2018-11-27 22:53:57+00:00  beaumont_police
# 14973  2018-08-28 02:59:23+00:00  beaumont_police
# 15370  2020-01-16 17:03:18+00:00  fortworthpd
# 15644  2019-09-12 18:38:57+00:00  fortworthpd
# 15675  2019-09-03 12:25:50+00:00  fortworthpd
# 15752  2019-08-08 21:49:39+00:00  fortworthpd
# 15760  2019-08-06 20:12:13+00:00  fortworthpd
# 15856  2019-07-08 11:41:05+00:00  fortworthpd
# 15867  2019-07-01 21:25:56+00:00  fortworthpd
# 15879  2019-06-28 19:39:24+00:00  fortworthpd
# 15890  2019-06-26 20:30:20+00:00  fortworthpd
# 15894  2019-06-26 16:05:23+00:00  fortworthpd
# 15908  2019-06-24 13:20:16+00:00  fortworthpd
# 15931  2019-06-18 16:10:47+00:00  fortworthpd
# 16097  2019-05-08 14:52:21+00:00  fortworthpd
# 16201  2019-04-13 15:17:36+00:00  fortworthpd
# 16216  2019-04-08 18:00:59+00:00  fortworthpd
# 16313  2019-03-11 19:32:52+00:00  fortworthpd
# 16362  2019-02-28 15:58:42+00:00  fortworthpd
# 16369  2019-02-28 14:42:42+00:00  fortworthpd
# 16370  2019-02-28 14:29:41+00:00  fortworthpd
# 16374  2019-02-28 14:00:00+00:00  fortworthpd
# 16378  2019-02-27 20:46:09+00:00  fortworthpd
# 16403  2019-02-20 19:24:09+00:00  fortworthpd
# 16503  2019-01-23 14:01:43+00:00  fortworthpd
# 16564  2019-01-02 14:43:35+00:00  fortworthpd
# 16594  2018-12-19 11:32:41+00:00  fortworthpd
#
#                                                                                                                                                                                                                                                                    tweet
# 4959   DallasPD and dfrincidents are currently on location in the  block of Main St regarding a suspicious package Roads are closed for safety precation at HarwoodMain St PearlCommerce PearlMain ChiefHallDPD
# 5684   Southbound Marsh Lane at Merrell Rd is currently closed due to a high centered  wheeler We will update the closure when reopened
# 5712   Gate   and  at the StateFairOfTX are full and closed for parking BigTex
# 5718   All entry gates to the StateFairOfTX are closed BigTex
# 5719   All parking gates are full and closed at the StateFairOfTX BigTex
# 5733   Gate  at the StateFairOfTX is full and closed for parking Gates  and  are open
# 5740   Gat  Valet parking is closed for parking StateFairOfTX BigTex
# 5744   TrafficAlert Gates  amp  are closed at the StateFairOfTX
# 5749   All gates at the StateFairOfTX are closed Only credential parking allowed in TexasFootball OUFootball RRShowdown BigTex ChiefHallDPD
# 5761   Gate  at the StateFairOfTX is closed Parking lot is full BigTex
# 5795   Parking for Gate  StateFairOfTX is full and closed for parking
# 5826   Gate code  StateFairOfTX is closed Parking lot is full Grambling PVAMU StateFairClassic ChiefHallDPD BigTex
# 5827   The following gates are closed at the StateFairOfTX Gates   and  PVAMU Grambling StateFairClassic BigTex ChiefHallDPD
# 5983   Monday Sept   on LaborDay Jack Evans Police Hdqtrs will be closed for business on Sept   in observance of LaborDayCesar E Chavez Holiday For specific details please go to  For nonemergency calls  call  For emergency calls  call
# 6062   PIODPD is at the scene of a possible barricaded person in the  block of Hillburn Dr Hillburn between Bruton Rd and Tillman St is closed in both directions Bruton Rd between Alhambra St and Gaylord Dr is also closed in both directions
# 6175   PIODPD is on scene of an Officer Involved Shooting in the  block of Great Trinity Forest Way Both roads of travel on Great Trinity Forest Way are closed between I and Haas Drive
# 6177   Major police incident in downtown Dallas Griffin Street between Main Street and Pacific is closed in both directions
# 6364   Due to the Crane Collapse on Live Oak the following streets are closed Good Latimer at Gaston Good Latimer at Live Oak Live Oak at Cantegral and Live Oak at Texas The Family Unification Center is located at The Latino Cultural Center located at  Live Oak
# 6699   Currently the  block of Trinity Mills Rd is closed DallasPd is assisting Dallas Fire Rescue with traffic as they work the structure fire
# 6749   DallasPD All previously closed streets are now open
# 6891   Road Closures MD Love I split remains shutdown due to an accident Also Spur  I is currently closed
# 6930   On the scene of officer involved shooting No injuries reported Fair Oaks Ave to Phoenix St closed More info will be released when it becomes available
# 7591   Gate  StateFairOfTX is closed to CASH parking TexasFootball OUFootball RedRiverShowdown BigTex StateFair
# 7806   Street closure both Northbound and Southbound N Jim Miller between Military Parkway and Parkdale Drive are closed at this time
# 7841   Per DallasFireResq due to a gas leak near  Pearl St in Downtown a construction crew hit a gas line PearlampFloraSt CLOSED Ross Ave from Olive to Pearl St is shut down while  Pearl is evacuated Also the exit from Woodall Rodgers Frwy to Pearl is shut down
# 7859   Traffic Advisory Due to a water main break downtown the    blocks of Elm will be closed and St Paul between Pacific and Main will be closed There is no estimated time on when the roads will reopen Please avoid this area
# 8137   Eastbound Commerce from Griffin St is closed and southbound Field St from Main St is closed and south bound Arkard Street from Main St
# 8231   The previously closed streets are now open Please be aware of increased pedestrian traffic in the area
# 8232   Saturday May  from  am to  pm Young Street between Ervay Street and Griffin Street will be closed and South Akard Street between Canton Street and Young Street will also be closed during the same time period Additional roads may be closed as needed
# 8428   The Dallas St Patricks Parade and Festival is this Saturday and several roads will be closed during the
# 8546   Momentarily eastbound I will be reopened However westbound I from Downtown Dallas including all lanes of traffic through the canyon to westbound I will be shutdown due to the ongoing investigation The updated closures will remain closed until further notice
# 8547   Traffic Update Additional Closures eastbound I at Hampton Road will be shutdown traffic will be diverted north  south onto Hampton Also eastbound Sylvan on ramp to I will be closed
# 8548   Be advised eastbound Interstate  is being shutdown at Sylvan Avenue All traffic will have to exit at Sylvan The freeway will remain closed until further notice due to police investigation
# 8550   Eastbound I  will be down to one lane from Sylvan Avenue to Commerce Street and Colorado Blvd exits due to police activity At this time the ramp to Texarkana east and south Waco are closed Please find alternate routes
# 9090   All gates are closed to cash parking Credentials only RedRiverRivalry StateFairOfTXBigTex
# 9095   Update Interstate  now has the left lanes open in both directions However the overpasss from  block of Marsalis Avenue remain closed Please be aware of work crews making repairs under the overpass
# 9163   Gate    StateFairOfTX are closed No parking available Grambling PVAMU StateFairClassic BigTex
# 9164   Gate  StateFairOfTX is closed  Parking is full Grambling PVAMU BigTex StateFairClassic
# 9207   The  blk of Cedar Springs Rd between King Rd and Mahanna St are closed off due to a barricaded person situation Please find alternate routes
# 9233   Traffic Alert Please avoid the southbound N Central Expressway service road at Northwest Highway The southbound exit ramp for Northwest Highway has also been temporarily closed due to a police incident
# 9504   There is a planned rally on  at  pm at City Hall Plaza Several streets in the area will be closed from  pm to  pm
# 9517   MLK Blvd from S Malcolm X Blvd to Latimer St is closed due to a police incident
# 9519   Major accident at intersection of Greenville Ave and Mockingbird WB Mockingbird and NB Greenville Ave closed please find alternate routes
# 10001  Lamar St  Belleview St has been closed We are asking that anyone in the vicinity stay clear until this incident is resolved  made safe
# 10263  There are several streets closed in the area of Dolphin and I Please avoid the area as this remains an active scene
# 10315  Due to police activity at  LBJ Freeway eastbound  Service Road is closed from Coit Road to Greenville Avenue
# 10583  TrafficAlert NB amp SB Harwood is closed from Commerce St to Elm St EB amp WB St Paul to Pearl street is also closed due to police incident
# 10629  The following roads remain closed Please avoid the area CommerceCesar Chavez MainPearl NB  ramp to Main St  ramp to NB
# 10630  Reminder The following roads are closed due to a fire incident ElmCesar Chavez CommerceHarwood CommercePearl JacksonPearl
# 10631  The Following also closed due to fire incident NB Central Expwyat ElmMain   Main  Ramp
# 10691  Case Closed Suspect Arrested for Murder on Leath Street
# 10726  Case Closed DallasPD detectives have arrested both suspects involved in this Capital Murder case
# 10925  As a result of an overturned  Wheeler SB Coit at PGB is closed due to debris on roadway TrafficAlert
# 11505  Jefferson Blvd is now open  Virginia Blvd remains closed The barricaded person location has been cleared The investigation is ongoing
# 11509  Roads or closed on Jefferson from Westmoreland to S Gilpin Ave and adjacent side streets The closures are related to the shooting
# 11606  All parking lots inside the StateFairOfTX are full All parking gates closed to in coming traffic TXvsOU
# 11610  ALL gates StateFairOfTX are full amp closed UTAustin UofOklahoma StateFairOfTx BigTex TXvsOU
# 11611  Gate  StateFairOfTX is full amp now closed TXvsOU UTAustin UofOklahoma DPDHumphrey BigTex
# 11828  TrafficAlert WB Lemmon Ave at Cole is closed due to a major accident
# 12814  NTTA TRAFFIC ADVISORY DALLAS NORTH TOLLWAY DNT Southbound DNT at IE ramp closed early morning on June
# 12838  March has ended Intersection at Cedar Springs and Oak Lawn is still closed Orlando Traffic is being rerouted
# 12842  The Southbound lanes of Cedar Springs frm Inwood to Oak Lawn are closed for the march Orlando
# 13641  DALLAS NORTH TOLLWAY DNT DNT at I ramp closed overnight April  for maintenance The southbound DNT to
# 14108  Both NB and SB exit ramps from EB  are closed due to an accident
# 14581  The MLK parade will be starting at am The following intersections have been closed  Cleveland  Gould
# 14741  Traffic Alert BPD is working a fatality crash in the  block of HWY  Both directions of travel are closed while the scene is under investigation Please seek an alternate route
# 14779  No The city is closed and nonessential services are suspended No trash service or public transportation Please stay off of the roads
# 14786  Most service roads are flooded and access to Interstate  and Highway  is extremely limited The City of Beaumont has closed nonessential offices for Thursday September   Lamar University LIT and BISD Schools are also closed
# 14809  Traffic Alert  College Street Westbound from I to rd is closed due to an  wheeler losing a heavy load of pipe It will be closed until crews can reload the pipes using a crane Please find an alternate route Washington Liberty Calder
# 14811  Traffic Alert HAZMAT Spill on IH Westbound at the Purple Heart Bridge Find an alternate route I Westbound coming into Beaumont from Orange County will be closed for several hours until the roadway is cleared
# 14844  Beaumont Police are on the scene of an Auto Pedestrian Fatality in the  block of West Cardinal Drive Southbound Drivers are being diverted off of the highway at Fannett Road This area of W Cardinal will be closed for several hours Please use caution
# 14882  Update Cardinal Dr Hwy  exit from IH is now open SouthEast bound traffic is moving Fannett Road exit will remain closed for several hours Use caution when traveling in this area as traffic is still congested
# 14883  Traffic Alert BPD is working a rollover crash and HAZMAT spill on Cardinal drive at Fannett Road SouthEast Bound At this time the Cardinal Dr Hwy  exit from IH is closed Expect delays in this area for several hours
# 14953  BPD is working a major traffic crash in the  block of Washington Blvd ALL Traffic lanes on Washington Blvd from Langham to Burbank are closed at this time Please take alternate routes and use caution in this area We will update when lanes are back open
# 14973  Traffic Alert BPD Investigating Fatality Crash at MLKFlorida Southbound lanes of MLK in this area will be closed for  hours  NB lanes are open traffic is moving slow Please use caution One confirmed Fatality Additional information will be released tomorrow
# 15370  ALERT A sink hole is at  E Rosedale right under the South Freeway overpass The two inside lanes will be closed for days maybe even weeks Plan accordingly
# 15644  RoadClosure Due to construction for the Trinity Railway Express bridge project the northbound Frontage road on I will be closed between E th Street amp the exit to IM Terrell  Friday Sept  at  am until Friday Sept  at  pm TrinityMetro
# 15675  RoadClosure Plan accordingly South Freeway will be closed between E th Street amp the exit to IM Terrell from  at  pm until  at  pm amp again on  at  pm to  at  pm Trinity Railway Express bridge project
# 15752  IW Northbound is closed at W Berry Street due to an overturned semi truck Please find alternate route
# 15760  TrafficAlert I Westbound before Hulen Left two lanes closed Small Vehicle fire
# 15856  RoadClosure  WB at Green Oaks is CLOSED due to a major accident Seek an alternate route TrafficAlert
# 15867  RoadClosure I SB is CLOSED at Heritage Trace due to a major accident Seek an alternate route TrafficAlert
# 15879  TrafficAlert EB I   ALL lanes at Hulen closed
# 15890  ALERT Due to construction for TrinityMetro bridge project IW North will be closed between E th St amp the exit to IM Terrell Closure takes place on June  Sat at  pm until July  Mon at  am RoadClosure
# 15894  ALERT I Eastbound at Chapel Creek is CLOSED due to an wheeler accident Seek an alternare route TrafficAlert
# 15908  ALERT West th will be CLOSED FROM June June  Plan accordingly
# 15931  PlanAccordingly Due to construction of the TrinityMetro bridge project I NB will be closed between E th St and the exit to IM Terrell from Saturday June  at  pm until Monday June  at  am
# 16097  HighWater E Berry St  block Closed off Avoid the area
# 16201  mainstreetarts is suspended amp closed due to severe weather Main Street will reopen on Sunday
# 16216  TrafficAlert I Eastbound at James multiple vehicle accident Two right lanes closed Expect lengthy delay
# 16313  Some lanes were closed because of cars having flat tires due to a load falling off an  wheeler
# 16362  RoadClosure Arborlawn ramp from NB Chisholm Trail is CLOSED
# 16369  RoadClosure Northbound Chisholm Trail at  is closed and  eastbound to northbound Chisholm Trail is also closed
# 16370  TrafficAlert Hemphill Bridge by Felix St is closed due to icy road conditions
# 16374  TRAFFICALERT The current streets are closed Lancaster bridge over E Loop  both directions NB entrance to Chisholm Trail from I Vehicles stuck blocking the entrance NB Hemphill from I  minute delay
# 16378  TrinityMetro construction of the new Sylvania Avenue Train bridge will begin on March  ap Two center lanes are expected to be closed until April Alert
# 16403  RoadClosure EB and WB I amp Chapel Creek Blvd over I will be closed between Feb   Feb   pm   am New bridge beams will be installed
# 16503  TrafficAlert Both sides of th Street at Decatur are closed  debris from a bridge is falling after being struck by truck Seek an alternate route
# 16564  TRAFFICALERT Road closures WB NW Loop  to NB IW amp SB IW NB and SB IW are closed at NE Loop
# 16594  TrafficAlert  Berry St is closed from Evans to Hemphill due to active Police Incident

# %%
df_1.shape
# Out:
# (14017, 3)

# %%
mask2_1 = df_1['tweet'].str.contains('parking', regex = False, case = False, na=False)
mask2_2 = df_1['tweet'].str.contains('gate', regex = False, case = False, na=False)
mask2_3 = df_1['tweet'].str.contains('parade', regex = False, case = False, na=False)
mask2_4 = df_1['tweet'].str.contains('amp', regex=False, case=False, na=False)
mask2_5 = df_1['tweet'].str.contains('StateFairOfTX', regex=False, case=False, na=False)

layer2 = (mask2_1 | mask2_2 | mask2_3 | mask2_4 | mask2_5)

# %%
df_2 = df_1[~layer2]

# %%
df_2.shape
# Out:
# (12147, 3)

# %%
df_2.head()
# Out:
#                      dates&time      user  \
# 4959  2020-02-06 22:03:12+00:00  DallasPD
# 5684  2019-10-23 18:36:51+00:00  DallasPD
# 5983  2019-08-30 21:16:20+00:00  DallasPD
# 6062  2019-08-14 22:31:39+00:00  DallasPD
# 6175  2019-07-13 22:04:27+00:00  DallasPD
#
#                                                                                                                                                                                                                                           tweet
# 4959  DallasPD and dfrincidents are currently on location in the  block of Main St regarding a suspicious package Roads are closed for safety precation at HarwoodMain St PearlCommerce PearlMain ChiefHallDPD
# 5684  Southbound Marsh Lane at Merrell Rd is currently closed due to a high centered  wheeler We will update the closure when reopened
# 5983  Monday Sept   on LaborDay Jack Evans Police Hdqtrs will be closed for business on Sept   in observance of LaborDayCesar E Chavez Holiday For specific details please go to  For nonemergency calls  call  For emergency calls  call
# 6062  PIODPD is at the scene of a possible barricaded person in the  block of Hillburn Dr Hillburn between Bruton Rd and Tillman St is closed in both directions Bruton Rd between Alhambra St and Gaylord Dr is also closed in both directions
# 6175  PIODPD is on scene of an Officer Involved Shooting in the  block of Great Trinity Forest Way Both roads of travel on Great Trinity Forest Way are closed between I and Haas Drive

# %%
# Second dataframe

#df_2 = df1[~mask_1]
#df_2 = df_2[~mask_2]

# %%
#df_1.duplicated().sum()

# %%
#df_1.drop_duplicates(keep='first', inplace = True)

# %%
#df_2['category '] = 0

# %%
#df_2.head()

# %%
#df_2.shape

# %% [markdown]
# ### Populate final dataframe.

# %%
#df_final = pd.concat([df_1, df_2])

# %%
#df_final['category '].value_counts()

# %%
#df_final = pd.to_csv('Final_data.csv')
